# %% [markdown]
# # Capstone Project: Boba Bao
# ## Applied Data Science Capstone by IBM/Coursera
# **Author:** Austin Tao
# **Date:** 01/04/2021
#
# ## Table of Contents
# * [Introduction/Business Problem](#introduction)
# * [Data](#data)
# * [Analysis Part 1:](#analysis)
#     * [San Francisco County](#sfcounty)
#     * [San Mateo County](#smcounty)
#     * [Santa Clara County](#sccounty)
#     * [Alameda County](#acounty)
#     * [Contra Costa County](#cccounty)
# * [Analysis Part 2:](#analysis2)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction/Business Problem: <a name="introduction"></a>
# In the Bay Area, the pearl milk tea market within the food and beverage industry is extremely competitive both between pearl milk tea stores and between other beverages. Consider the scenario where you want to open a new pearl milk tea store in the Bay Area.
#
# **Business Problem: If you are a businessperson looking to start a new bubble tea store in the Silicon Valley area, where would you plan to locate your store?**

# %% [markdown]
# ## Data: <a name = "data"></a>
# The data that will be worked with will be a combination of Foursquare location data and data from the `bayarea_boba_spots.csv` available [here](https://www.kaggle.com/vnxiclaire/bobabayarea). The csv file will primarily be used to compare between two boba shops, while Foursquare location data will be used to assess generalized venues in areas (i.e. businesses outside of the bubble tea sector). **In short, Foursquare will be used to analyze generalized location data while the aforementioned csv file will be used solely to compare bubble tea data.**
#
# To determine the optimal location for a new store, the following features will be analyzed:
# - Number of stores in the area that sell comparable goods
# - Number of other milk tea stores in the area directly competing
# - Popularity of said other milk tea stores

# %% [markdown]
# # Analysis Part 1: <a name = "analysis"></a>
#
# ## Gathering Neighborhood Data:

# %%
import pandas as pd
import numpy as np
import geopy
import requests
import folium

# %%
df = pd.read_csv("bayarea_boba_spots.csv")
df.head()
# Out:
#    Unnamed: 0                               id                   name  rating  \
# 0           0           99-tea-house-fremont-2          99% Tea House     4.5
# 1           1                one-tea-fremont-2                One Tea     4.5
# 2           2             royaltea-usa-fremont           Royaltea USA     4.0
# 3           3  teco-tea-and-coffee-bar-fremont  TECO Tea & Coffee Bar     4.5
# 4           4                  t-lab-fremont-3                  T-LAB     4.0
#
#                    address     city        lat        long
# 0        3623 Thornton Ave  Fremont  37.562950 -122.010040
# 1  46809 Warm Springs Blvd  Fremont  37.489067 -121.929414
# 2       38509 Fremont Blvd  Fremont  37.551315 -121.993850
# 3   39030 Paseo Padre Pkwy  Fremont  37.553694 -121.981043
# 4       34133 Fremont Blvd  Fremont  37.576149 -122.043705

# %% [markdown]
# ## Removing Unnecessary Columns:

# %%
df = df.drop(['Unnamed: 0', 'id'], axis = 1)
df.head()
# Out:
#                     name  rating                  address     city        lat  \
# 0          99% Tea House     4.5        3623 Thornton Ave  Fremont  37.562950
# 1                One Tea     4.5  46809 Warm Springs Blvd  Fremont  37.489067
# 2           Royaltea USA     4.0       38509 Fremont Blvd  Fremont  37.551315
# 3  TECO Tea & Coffee Bar     4.5   39030 Paseo Padre Pkwy  Fremont  37.553694
# 4                  T-LAB     4.0       34133 Fremont Blvd  Fremont  37.576149
#
#          long
# 0 -122.010040
# 1 -121.929414
# 2 -121.993850
# 3 -121.981043
# 4 -122.043705

# %% [markdown]
# ## Using geopy and folium to plot map of Bay Area:

# %%
from geopy.geocoders import Nominatim

address = 'San Francisco, California'

geolocator = Nominatim(user_agent = "ca_explorer")
location = geolocator.geocode(address)
sf_latitude = location.latitude
sf_longitude = location.longitude
print('The geograpical coordinate of San Francisco, California are {}, {}.'.format(sf_latitude, sf_longitude))
# Out:
# The geograpical coordinate of San Francisco, California are 37.7790262, -122.4199061.

# %%
map_bayArea = folium.Map(location = [sf_latitude, sf_longitude], zoom_start = 10)

# add markers to map
for lat, lng, city in zip(df['lat'], df['long'], df['city']):
    label = '{}'.format(city)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius = 5,
        popup = label,
        color = 'blue',
        fill = True,
        fill_color = '#3186cc',
        fill_opacity = 0.7,
        parse_html = False).add_to(map_bayArea)  
    
map_bayArea
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_314f2b5aca44478b83247774c823469f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_314f2b5aca44478b83247774c823469f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_314f2b5aca44478b83247774c823469f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_314f2b5aca44478b83247774c823469f%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B37.7790262%2C-122.4199061%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# # Splitting data for analysis
# Given the size of the Bay Area, it makes sense to split the data into groups by county and then perform analysis. **The data will be divided into five counties: San Francisco, San Mateo, Santa Clara, Alameda, and Contra Costa.**

# %% [markdown]
# # 1. San Francisco County: <a name = "sfcounty"></a>

# %%
df_sf = df[df['city'].isin(['San Francisco', 'san francisco'])].reset_index(drop = True)
df_sf.head()
# Out:
#                        name  rating           city        lat        long
# 0                 Boba Guys     4.0  San Francisco  37.789943 -122.407306
# 1                 Boba Guys     4.0  San Francisco  37.759940 -122.421120
# 2  Wonderful Dessert & Cafe     4.0  San Francisco  37.763325 -122.479878
# 3              Little Sweet     4.0  San Francisco  37.781425 -122.460802
# 4                  Teaspoon     4.0  San Francisco  37.796316 -122.421976

# %% [markdown]
# ## Define method mapCounty that maps our counties
# - @param df_county is the data frame of the county
# - @param venue_color is the desired border color for markers
# - @param venue_fill_color is the desired fill color for markers

# %%
def mapCounty(df_county, venue_color, venue_fill_color):
    map_sf = folium.Map(location = [sf_latitude, sf_longitude], zoom_start = 10)

    # add markers to map
    for lat, lng, city in zip(df_county['lat'], df_county['long'], df_county['city']):
        label = '{}'.format(city)
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius = 5,
            popup = label,
            color = venue_color,
            fill = True,
            fill_color = venue_fill_color,
            fill_opacity = 0.7,
            parse_html = False).add_to(map_sf)
    return(map_sf)
    
mapCounty(df_sf, 'red', '#cc2121')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_0b25922f40bc4258b8b510f7f5a502ba%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0b25922f40bc4258b8b510f7f5a502ba%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0b25922f40bc4258b8b510f7f5a502ba%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_0b25922f40bc4258b8b510f7f5a502ba%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B37.7790262%2C-122.4199061%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Using Foursquare data to explore the county:

# %%
CLIENT_ID = 'AHPAIMN1XFGEWLT4QRX5FO1ZQVRR5O3ICNCM0GJUOMEGPJBH'
CLIENT_SECRET = '41KRUQ3PIH25L5RVQ5T23F0ZPPVJ2VG0PIPZMDB2IG5ZXBJU'
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: AHPAIMN1XFGEWLT4QRX5FO1ZQVRR5O3ICNCM0GJUOMEGPJBH
# CLIENT_SECRET:41KRUQ3PIH25L5RVQ5T23F0ZPPVJ2VG0PIPZMDB2IG5ZXBJU

# %% [markdown]
# ## Define a function to get all venues in the county:

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
sf_venues = getNearbyVenues(names = df_sf['city'],
                                   latitudes = df_sf['lat'],
                                   longitudes = df_sf['long']
                                  )
sf_venues.head(10)
# Out:
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
# San Francisco
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  San Francisco              37.789943             -122.407306
# 1  San Francisco              37.789943             -122.407306
# 2  San Francisco              37.789943             -122.407306
# 3  San Francisco              37.789943             -122.407306
# 4  San Francisco              37.789943             -122.407306
# 5  San Francisco              37.789943             -122.407306
# 6  San Francisco              37.789943             -122.407306
# 7  San Francisco              37.789943             -122.407306
# 8  San Francisco              37.789943             -122.407306
# 9  San Francisco              37.789943             -122.407306
#
#                        Venue  Venue Latitude  Venue Longitude  \
# 0                The Archive       37.789494      -122.405766
# 1            Williams-Sonoma       37.788377      -122.407446
# 2              Tiffany & Co.       37.788598      -122.407708
# 3            Maison Margiela       37.788261      -122.405765
# 4            The Whisky Shop       37.789494      -122.406554
# 5           Pure Organic Spa       37.789286      -122.409191
# 6         Apple Union Square       37.788690      -122.407174
# 7          Benefit Cosmetics       37.789898      -122.404934
# 8               Union Square       37.787933      -122.407501
# 9  Grand Hyatt San Francisco       37.789070      -122.407168
#
#          Venue Category
# 0           Men's Store
# 1  Kitchen Supply Store
# 2         Jewelry Store
# 3              Boutique
# 4          Liquor Store
# 5                   Spa
# 6     Electronics Store
# 7        Cosmetics Shop
# 8      Pedestrian Plaza
# 9                 Hotel

# %%
sf_grouped = sf_venues.groupby(['Venue Category']).count()
sf_grouped = sf_grouped.drop(['Neighborhood', 'Neighborhood Latitude', 'Neighborhood Longitude', 'Venue Latitude', 'Venue Longitude'], axis = 1)
sf_grouped = sf_grouped.sort_values(by = 'Venue', ascending = False)
sf_grouped.head(5)
# Out:
#                     Venue
# Venue Category
# Chinese Restaurant    155
# Coffee Shop           137
# Bakery                120
# Bubble Tea Shop        90
# Café                   89

# %% [markdown]
# From the `sf_grouped` data frame above, it's clear that venues that sell goods comparable to pearl milk tea are among the top retail venues in San Francisco county ("Coffee Shop", "Bakery", "Cafe", and "Bubble Tea Shop" all sell comparable goods). The popularity of these stores means competition would be fierce when opening a new pearl milk tea store, making SF county not the most desirable place for opening a store.

# %% [markdown]
# # 2. San Mateo County: <a name = "smcounty"></a>

# %%
df_sanMateo = df[df['city'].isin(['Atherton', 'Belmont', 'Brisbane', 'Burlingame', 'Colma', 'Daly City', 'East Palo Alto', 'Foster City', 'Half Moon Bay', 'Hillsborough', 'Menlo Park', 'Millbrae', 'Pacifica', 'Portola Valley', 'Redwood City', 'San Bruno', 'San Carlos', 'San Mateo', 'South San Francisco', 'Woodside'])].reset_index(drop = True)
df_sanMateo.head()
# Out:
#          name  rating          city        lat        long
# 0     FrosTea     3.5     Daly City  37.706890 -122.458800
# 1  The Burrow     4.5      Brisbane  37.683464 -122.402889
# 2   Boba Guys     4.0    San Carlos  37.502740 -122.256980
# 3  Teaquation     4.5  Redwood City  37.483951 -122.232654
# 4     Chatime     4.0  Redwood City  37.487118 -122.229624

# %% [markdown]
# ## Mapping San Mateo Milk Tea Stores:

# %%
mapCounty(df_sanMateo, 'blue', '#1798e8')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_9d9053883ceb40148789f58e00dd2c89%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9d9053883ceb40148789f58e00dd2c89%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_9d9053883ceb40148789f58e00dd2c89%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_9d9053883ceb40148789f58e00dd2c89%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B37.7790262%2C-122.4199061%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Finding Venues in San Mateo:

# %%
sanMateo_venues = getNearbyVenues(names = df_sanMateo['city'],
                                   latitudes = df_sanMateo['lat'],
                                   longitudes = df_sanMateo['long']
                                  )
sanMateo_venues.head()
# Out:
# Daly City
# Brisbane
# San Carlos
# Redwood City
# Redwood City
# Redwood City
# Redwood City
# Redwood City
# Redwood City
# Redwood City
# Menlo Park
# Redwood City
# Redwood City
# Redwood City
# Menlo Park
# South San Francisco
# Burlingame
# San Bruno
# San Mateo
# Burlingame
# South San Francisco
# Burlingame
# San Mateo
# San Mateo
# Millbrae
# Pacifica
# Millbrae
# Burlingame
# Half Moon Bay
# Millbrae
# San Mateo
# South San Francisco
# San Mateo
# San Mateo
# San Mateo
# San Mateo
# Foster City
# San Mateo
# Foster City
# San Mateo
# San Mateo
# Belmont
# San Mateo
# San Mateo
# San Carlos
# Millbrae
# San Mateo
# San Mateo
# Burlingame
# San Mateo
# Foster City
# Foster City
# San Mateo
# San Mateo
# San Mateo
# San Mateo
# Burlingame
# San Bruno
# Burlingame
# San Mateo
# Millbrae
# San Mateo
# Millbrae
# Belmont
# Foster City
# Foster City
# Belmont
# San Mateo
# Foster City
# San Mateo
# San Mateo
# San Mateo
# Redwood City
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude           Venue  \
# 0    Daly City               37.70689               -122.4588      Goldilocks
# 1    Daly City               37.70689               -122.4588  Noodle Station
# 2    Daly City               37.70689               -122.4588         Tselogs
# 3    Daly City               37.70689               -122.4588     Dollar Tree
# 4    Daly City               37.70689               -122.4588    Bart Grocery
#
#    Venue Latitude  Venue Longitude     Venue Category
# 0       37.706713      -122.459872             Bakery
# 1       37.707504      -122.455777       Noodle House
# 2       37.706864      -122.458855             Lounge
# 3       37.706397      -122.460073     Discount Store
# 4       37.705672      -122.464151  Korean Restaurant

# %% [markdown]
# ## Doing one-hot-encoding now that there are multiple cities:

# %%
def oneHotEncoding(county_venues):
    # one hot encoding
    county_onehot = pd.get_dummies(county_venues[['Venue Category']], prefix="", prefix_sep="")

    # add neighborhood column back to dataframe
    county_onehot['Neighborhood'] = county_venues['Neighborhood'] 

    # move neighborhood column to the first column
    fixed_columns = [county_onehot.columns[-1]] + list(county_onehot.columns[:-1])
    county_onehot = county_onehot[fixed_columns]

    return county_onehot.groupby('Neighborhood').mean().reset_index()

sanMateo_grouped = oneHotEncoding(sanMateo_venues)
sanMateo_grouped.head()
# Out:
#   Neighborhood       ATM  Afghan Restaurant  American Restaurant  \
# 0      Belmont  0.019417                0.0             0.000000
# 1     Brisbane  0.000000                0.0             0.000000
# 2   Burlingame  0.000000                0.0             0.018576
# 3    Daly City  0.000000                0.0             0.000000
# 4  Foster City  0.000000                0.0             0.000000
#
#    Antique Shop  Argentinian Restaurant  Art Gallery  Arts & Crafts Store  \
# 0           0.0                     0.0          0.0              0.00000
# 1           0.0                     0.0          0.0              0.00000
# 2           0.0                     0.0          0.0              0.01548
# 3           0.0                     0.0          0.0              0.00000
# 4           0.0                     0.0          0.0              0.00000
#
#    Asian Restaurant  Auditorium  ...  Video Game Store  Video Store  \
# 0          0.009709         0.0  ...               0.0     0.000000
# 1          0.000000         0.0  ...               0.0     0.000000
# 2          0.030960         0.0  ...               0.0     0.003096
# 3          0.041667         0.0  ...               0.0     0.000000
# 4          0.000000         0.0  ...               0.0     0.032680
#
#    Vietnamese Restaurant  Warehouse Store  Weight Loss Center  Wine Bar  \
# 0               0.009709         0.000000                 0.0       0.0
# 1               0.083333         0.000000                 0.0       0.0
# 2               0.000000         0.000000                 0.0       0.0
# 3               0.041667         0.000000                 0.0       0.0
# 4               0.006536         0.006536                 0.0       0.0
#
#    Wine Shop  Wings Joint  Women's Store  Yoga Studio
# 0        0.0          0.0            0.0     0.000000
# 1        0.0          0.0            0.0     0.000000
# 2        0.0          0.0            0.0     0.003096
# 3        0.0          0.0            0.0     0.000000
# 4        0.0          0.0            0.0     0.000000
#
# [5 rows x 220 columns]

# %% [markdown]
# ## Finding the top venues in each neighborhood:

# %%
num_top_venues = 5

def findTopVenues(county_grouped, num_top_venues):
    for hood in county_grouped['Neighborhood']:
        print("----"+hood+"----")
        temp = county_grouped[county_grouped['Neighborhood'] == hood].T.reset_index()
        temp.columns = ['venue','freq']
        temp = temp.iloc[1:]
        temp['freq'] = temp['freq'].astype(float)
        temp = temp.round({'freq': 2})
        print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
        print('\n')
        
findTopVenues(sanMateo_grouped, num_top_venues)
# Out:
# ----Belmont----
#               venue  freq
# 0     Grocery Store  0.05
# 1    Sandwich Place  0.04
# 2  Sushi Restaurant  0.04
# 3        Nail Salon  0.04
# 4       Coffee Shop  0.04
#
#
# ----Brisbane----
#                    venue  freq
# 0                   Park  0.12
# 1  Vietnamese Restaurant  0.08
# 2     Mexican Restaurant  0.08
# 3         Sandwich Place  0.04
# 4       Sushi Restaurant  0.04
#
#
# ----Burlingame----
#              venue  freq
# 0      Pizza Place  0.06
# 1  Bubble Tea Shop  0.05
# 2   Sandwich Place  0.04
# 3      Coffee Shop  0.04
# 4           Bakery  0.04
#
#
# ----Daly City----
#                 venue  freq
# 0                Café  0.08
# 1      Discount Store  0.04
# 2  Burmese Restaurant  0.04
# 3     Bubble Tea Shop  0.04
# 4   Convenience Store  0.04
#
#
# ----Foster City----
#                 venue  freq
# 0                Park  0.05
# 1         Pizza Place  0.05
# 2  Chinese Restaurant  0.04
# 3     Bubble Tea Shop  0.04
# 4      Shipping Store  0.04
#
#
# ----Half Moon Bay----
#                 venue  freq
# 0       Grocery Store  0.09
# 1         Coffee Shop  0.09
# 2                 ATM  0.06
# 3  Frozen Yogurt Shop  0.06
# 4         Pizza Place  0.06
#
#
# ----Menlo Park----
#             venue  freq
# 0     Coffee Shop  0.10
# 1            Park  0.10
# 2           Hotel  0.07
# 3  Cosmetics Shop  0.07
# 4          Bakery  0.07
#
#
# ----Millbrae----
#                    venue  freq
# 0     Chinese Restaurant  0.11
# 1  Vietnamese Restaurant  0.04
# 2                 Bakery  0.03
# 3          Grocery Store  0.03
# 4     Seafood Restaurant  0.03
#
#
# ----Pacifica----
#             venue  freq
# 0            Café  0.06
# 1        Dive Bar  0.06
# 2   Fishing Store  0.06
# 3  Sandwich Place  0.06
# 4             Gym  0.03
#
#
# ----Redwood City----
#                 venue  freq
# 0  Mexican Restaurant  0.06
# 1         Coffee Shop  0.05
# 2      Sandwich Place  0.04
# 3                Café  0.03
# 4        Burger Joint  0.03
#
#
# ----San Bruno----
#                  venue  freq
# 0   Mexican Restaurant  0.06
# 1  Filipino Restaurant  0.05
# 2     Sushi Restaurant  0.05
# 3   Chinese Restaurant  0.04
# 4                  Spa  0.03
#
#
# ----San Carlos----
#                  venue  freq
# 0  American Restaurant  0.06
# 1   Mexican Restaurant  0.06
# 2       Sandwich Place  0.06
# 3     Sushi Restaurant  0.05
# 4       Ice Cream Shop  0.05
#
#
# ----San Mateo----
#                  venue  freq
# 0  Japanese Restaurant  0.07
# 1   Chinese Restaurant  0.05
# 2   Mexican Restaurant  0.05
# 3        Grocery Store  0.03
# 4          Coffee Shop  0.03
#
#
# ----South San Francisco----
#                   venue  freq
# 0    Chinese Restaurant  0.07
# 1           Pizza Place  0.07
# 2    Mexican Restaurant  0.06
# 3  Fast Food Restaurant  0.05
# 4              Pharmacy  0.05

# %% [markdown]
# Of the 14 cities, 9 of them (approximately 64%) contained a top venue comparable to pearl milk tea. This is better than San Francisco County, but is not enough to determine that this is an appropriate county.

# %% [markdown]
# # 3. Santa Clara County: <a name = "sccounty"></a>

# %%
df_scc = df[df['city'].isin(['Campbell', 'Cupertino', 'Gilroy', 'Los Altos', 'Los Altos Hills', 'Los Gatos', 'Milpitas', 'Monte Sereno', 'Morgan Hill', 'Mountain View', 'Palo Alto', 'San Jose', 'Santa Clara', 'Saratoga', 'Sunnyvale'])].reset_index(drop = True)
df_scc.head()
# Out:
#           name  rating               address           city        lat  \
# 0      Tea Era     4.0         271 Castro St  Mountain View  37.392956
# 1     Teaspoon     4.0   4546 El Camino Real      Los Altos  37.401254
# 2       Tastea     4.0    1160 N Capitol Ave       San Jose  37.387800
# 3    Tea Villa     4.0  1679 N Milpitas Blvd       Milpitas  37.454735
# 4  Pop Tea Bar     4.0     456 Cambridge Ave      Palo Alto  37.426550
#
#          long
# 0 -122.079281
# 1 -122.114469
# 2 -121.860190
# 3 -121.911572
# 4 -122.146320

# %% [markdown]
# ## Mapping Santa Clara County Boba Stores:

# %%
mapCounty(df_scc, 'yellow', '#e6ed13')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_e07ea785121f40c981c4541c9f8f5ed0%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e07ea785121f40c981c4541c9f8f5ed0%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e07ea785121f40c981c4541c9f8f5ed0%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_e07ea785121f40c981c4541c9f8f5ed0%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B37.7790262%2C-122.4199061%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Venues in Santa Clara County:

# %%
scc_venues = getNearbyVenues(names = df_scc['city'],
                                   latitudes = df_scc['lat'],
                                   longitudes = df_scc['long']
                                  )
scc_venues.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-115-30b036e36687> in <module>
#       1 scc_venues = getNearbyVenues(names = df_scc['city'],
#       2                                    latitudes = df_scc['lat'],
# ----> 3                                    longitudes = df_scc['long']
#       4                                   )
#       5 scc_venues.head()
#
# <ipython-input-29-e3b5b3de6c4b> in getNearbyVenues(names, latitudes, longitudes, radius)
#      16
#      17         # make the GET request
# ---> 18         results = requests.get(url).json()["response"]['groups'][0]['items']
#      19
#      20         # return only relevant information for each nearby venue
#
# KeyError: 'groups'

# %% [markdown]
# ## One-hot-encoding:

# %%
scc_grouped = oneHotEncoding(scc_venues)
scc_grouped.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-de38375c70d4> in <module>
# ----> 1 scc_grouped = oneHotEncoding(scc_venues)
#       2 scc_grouped.head()
#
# NameError: name 'scc_venues' is not defined

# %% [markdown]
# ## Finding top venues in each city:

# %%
findTopVenues(scc_grouped, num_top_venues)

# %% [markdown]
# Every single one of the cities in Santa Clara county had either coffee shop, cafe, or milk tea shop, meaning that there would be extremely strong competition opening a new pearl milk tea store in this county.

# %% [markdown]
# # 4. Alameda County: <a name = "acounty"></a>

# %%
df_alameda = df[df['city'].isin(['Alameda', 'Albany', 'Berkeley', 'Dublin', 'Emeryville', 'Fremont', 'Hayward', 'Livermore', 'Newark', 'Oakland', 'Piedmont', 'Pleasanton', 'San Leandro', 'Union City'])].reset_index(drop = True)
df_alameda.head()
# Out:
#                     name  rating     city        lat        long
# 0          99% Tea House     4.5  Fremont  37.562950 -122.010040
# 1                One Tea     4.5  Fremont  37.489067 -121.929414
# 2           Royaltea USA     4.0  Fremont  37.551315 -121.993850
# 3  TECO Tea & Coffee Bar     4.5  Fremont  37.553694 -121.981043
# 4                  T-LAB     4.0  Fremont  37.576149 -122.043705

# %% [markdown]
# ## Mapping Boba Stores in Alameda County:

# %%
mapCounty(df_alameda, 'grey', '#C0C0C0')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_9e49f19898414d65b548a3d405aa4096%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9e49f19898414d65b548a3d405aa4096%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_9e49f19898414d65b548a3d405aa4096%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_9e49f19898414d65b548a3d405aa4096%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B37.7790262%2C-122.4199061%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Finding venues in Alameda County:

# %%
alameda_venues = getNearbyVenues(names = df_alameda['city'],
                                   latitudes = df_alameda['lat'],
                                   longitudes = df_alameda['long']
                                  )
alameda_venues.head()
# Out:
# Fremont
# Fremont
# Fremont
# Fremont
# Fremont
# Newark
# Fremont
# Fremont
# Fremont
# Fremont
# Fremont
# Fremont
# Fremont
# Fremont
# Newark
# Fremont
# Fremont
# Newark
# Newark
# Fremont
# Fremont
# Newark
# Fremont
# Fremont
# Fremont
# Union City
# Fremont
# Fremont
# Fremont
# Fremont
# Union City
# Union City
# Newark
# Union City
# Union City
# Fremont
# Fremont
# Union City
# San Leandro
# Oakland
# Oakland
# Oakland
# Berkeley
# Oakland
# Berkeley
# Alameda
# Oakland
# Oakland
# Berkeley
# Berkeley
# Berkeley
# Alameda
# Berkeley
# Alameda
# Oakland
# Oakland
# Alameda
# Oakland
# San Leandro
# Oakland
# Berkeley
# Oakland
# Oakland
# Alameda
# Alameda
# Oakland
# Oakland
# Oakland
# Oakland
# San Leandro
# Oakland
# Berkeley
# Oakland
# Pleasanton
# Pleasanton
# Dublin
# Pleasanton
# Pleasanton
# Dublin
# Dublin
# Pleasanton
# Dublin
# Dublin
# Pleasanton
# Pleasanton
# Pleasanton
# Pleasanton
# Dublin
# Dublin
# Pleasanton
# Pleasanton
# Dublin
# Dublin
# Dublin
# Pleasanton
# Pleasanton
# Dublin
# Dublin
# Pleasanton
# Pleasanton
# Dublin
# Dublin
# Dublin
# Dublin
# Livermore
# Pleasanton
# Dublin
# Dublin
# Dublin
# Dublin
# Dublin
# Dublin
# Dublin
# Dublin
# Newark
# Union City
# Newark
# Newark
# Union City
# Fremont
# Newark
# Fremont
# Newark
# Union City
# Newark
# Fremont
# Union City
# Fremont
# Fremont
# Hayward
# Hayward
# Hayward
# Livermore
# Livermore
# Livermore
# Livermore
# Livermore
# Livermore
# Livermore
# Fremont
# Fremont
# Fremont
# Oakland
# Albany
# Berkeley
# Berkeley
# Hayward
# Hayward
# Hayward
# San Leandro
# Hayward
# San Leandro
# San Leandro
# San Leandro
# San Leandro
# San Leandro
# San Leandro
# San Leandro
# San Leandro
# San Leandro
# Alameda
# San Leandro
# San Leandro
# San Leandro
# Alameda
# Oakland
# Alameda
# Hayward
# San Leandro
# San Leandro
# San Leandro
# Hayward
# San Leandro
# Hayward
# Hayward
# San Leandro
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0      Fremont               37.56295              -122.01004
# 1      Fremont               37.56295              -122.01004
# 2      Fremont               37.56295              -122.01004
# 3      Fremont               37.56295              -122.01004
# 4      Fremont               37.56295              -122.01004
#
#                               Venue  Venue Latitude  Venue Longitude  \
# 0                      Satomi Sushi       37.562808      -122.010448
# 1               Suju's Coffee & Tea       37.562694      -122.009259
# 2                       Bun Appétit       37.559883      -122.009978
# 3          Dino's Family Restaurant       37.561186      -122.012218
# 4  Kyain Kyain (Main Main Kyay Ohe)       37.562900      -122.010341
#
#      Venue Category
# 0  Sushi Restaurant
# 1       Coffee Shop
# 2        Donut Shop
# 3             Diner
# 4        Soup Place

# %% [markdown]
# ## One-hot-encoding for Alameda County:

# %%
alameda_grouped = oneHotEncoding(alameda_venues)
alameda_grouped.head()
# Out:
#   Neighborhood       ATM  Accessories Store  Adult Boutique  \
# 0      Alameda  0.007949           0.007949             0.0
# 1       Albany  0.000000           0.000000             0.0
# 2     Berkeley  0.000000           0.015385             0.0
# 3       Dublin  0.004963           0.000000             0.0
# 4      Fremont  0.003425           0.000000             0.0
#
#    Afghan Restaurant  African Restaurant  Airport  Airport Terminal  \
# 0           0.011129             0.00159      0.0               0.0
# 1           0.000000             0.00000      0.0               0.0
# 2           0.000000             0.00000      0.0               0.0
# 3           0.003722             0.00000      0.0               0.0
# 4           0.000000             0.00000      0.0               0.0
#
#    American Restaurant  Andhra Restaurant  ...  Vietnamese Restaurant  \
# 0             0.023847                0.0  ...               0.012719
# 1             0.000000                0.0  ...               0.000000
# 2             0.015385                0.0  ...               0.007692
# 3             0.006203                0.0  ...               0.007444
# 4             0.008562                0.0  ...               0.017979
#
#    Warehouse Store  Weight Loss Center  Wine Bar  Wine Shop  Winery  \
# 0         0.000000                 0.0  0.019078   0.014308     0.0
# 1         0.000000                 0.0  0.000000   0.000000     0.0
# 2         0.000000                 0.0  0.000000   0.000000     0.0
# 3         0.000000                 0.0  0.000000   0.000000     0.0
# 4         0.003425                 0.0  0.000000   0.003425     0.0
#
#    Wings Joint  Women's Store  Xinjiang Restaurant  Yoga Studio
# 0     0.004769            0.0                  0.0     0.000000
# 1     0.000000            0.0                  0.0     0.000000
# 2     0.003077            0.0                  0.0     0.013846
# 3     0.002481            0.0                  0.0     0.000000
# 4     0.005993            0.0                  0.0     0.000000
#
# [5 rows x 307 columns]

# %% [markdown]
# ## Finding top venues in Alameda:

# %%
findTopVenues(alameda_grouped, num_top_venues)
# Out:
# ----Alameda----
#                 venue  freq
# 0      Sandwich Place  0.03
# 1     Bubble Tea Shop  0.03
# 2                 Bar  0.03
# 3  Chinese Restaurant  0.03
# 4         Pizza Place  0.02
#
#
# ----Albany----
#                venue  freq
# 0    Thai Restaurant  0.07
# 1  Indian Restaurant  0.07
# 2                Bar  0.04
# 3        Pizza Place  0.04
# 4          Pet Store  0.04
#
#
# ----Berkeley----
#              venue  freq
# 0      Coffee Shop  0.05
# 1             Café  0.04
# 2  Thai Restaurant  0.03
# 3   Sandwich Place  0.02
# 4    Hot Dog Joint  0.02
#
#
# ----Dublin----
#                  venue  freq
# 0          Coffee Shop  0.05
# 1       Sandwich Place  0.04
# 2  Japanese Restaurant  0.04
# 3               Bakery  0.03
# 4        Grocery Store  0.03
#
#
# ----Fremont----
#                   venue  freq
# 0    Chinese Restaurant  0.07
# 1       Bubble Tea Shop  0.05
# 2           Pizza Place  0.04
# 3           Coffee Shop  0.04
# 4  Fast Food Restaurant  0.03
#
#
# ----Hayward----
#                 venue  freq
# 0  Mexican Restaurant  0.07
# 1         Coffee Shop  0.03
# 2    Sushi Restaurant  0.03
# 3                 Bar  0.03
# 4         Pizza Place  0.03
#
#
# ----Livermore----
#                 venue  freq
# 0      Clothing Store  0.09
# 1          Shoe Store  0.04
# 2         Pizza Place  0.04
# 3      Sandwich Place  0.04
# 4  Mexican Restaurant  0.04
#
#
# ----Newark----
#                  venue  freq
# 0   Chinese Restaurant  0.07
# 1  Japanese Restaurant  0.04
# 2          Pizza Place  0.03
# 3                Hotel  0.03
# 4    Korean Restaurant  0.03
#
#
# ----Oakland----
#                    venue  freq
# 0     Chinese Restaurant  0.06
# 1                   Café  0.05
# 2            Coffee Shop  0.04
# 3  Vietnamese Restaurant  0.03
# 4                 Bakery  0.03
#
#
# ----Pleasanton----
#             venue  freq
# 0     Coffee Shop  0.05
# 1     Pizza Place  0.04
# 2  Clothing Store  0.04
# 3  Sandwich Place  0.03
# 4   Grocery Store  0.03
#
#
# ----San Leandro----
#                    venue  freq
# 0       Sushi Restaurant  0.05
# 1            Pizza Place  0.05
# 2                   Bank  0.04
# 3     Chinese Restaurant  0.04
# 4  Vietnamese Restaurant  0.03
#
#
# ----Union City----
#                    venue  freq
# 0  Vietnamese Restaurant  0.06
# 1          Grocery Store  0.06
# 2        Thai Restaurant  0.05
# 3       Asian Restaurant  0.05
# 4       Ramen Restaurant  0.04

# %% [markdown]
# Only 7 of the 12 (approximately 58%) of the cities in Alameda County have a venue that sells goods that compete with pearl milk tea in their top 5 venues. This is a good sign and means that Alameda County is potentially a good contender for opening a new store.

# %% [markdown]
# # 5. Contra Costa County: <a name = "cccounty"></a>

# %%
df_ccc = df[df['city'].isin(['Antioch', 'Brentwood', 'Clayton', 'Concord', 'Danville', 'El Cerrito', 'Hercules', 'Lafayette', 'Martinez', 'Moraga', 'Oakley', 'Orinda', 'Pinole', 'Pittsburg', 'Pleasant Hill', 'Richmond', 'San Pablo', 'San Ramon', 'Walnut Creek'])].reset_index(drop = True)
df_ccc.head()
# Out:
#                       name  rating           city        lat        long
# 0             Milk Tea Lab     4.0  Pleasant Hill  37.948571 -122.058179
# 1                    i-Tea     4.0   Walnut Creek  37.898132 -122.059291
# 2                       T4     3.5      San Ramon  37.730210 -121.930090
# 3                    i-Tea     4.0      San Ramon  37.724100 -121.944350
# 4  Pho Saigon Noodle House     3.5      San Ramon  37.729389 -121.931442

# %% [markdown]
# ## Mapping Boba Stores in Contra Costa County:

# %%
mapCounty(df_ccc, 'purple', '#800080')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_1e81fa7b56fb445da480dd35ca6c7b55%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1e81fa7b56fb445da480dd35ca6c7b55%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_1e81fa7b56fb445da480dd35ca6c7b55%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_1e81fa7b56fb445da480dd35ca6c7b55%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B37.7790262%2C-122.4199061%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Venues in Contra Costa County:

# %%
ccc_venues = getNearbyVenues(names = df_ccc['city'],
                                   latitudes = df_ccc['lat'],
                                   longitudes = df_ccc['long']
                                  )
ccc_venues.head()
# Out:
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Pleasant Hill              37.948571             -122.058179
# 1  Pleasant Hill              37.948571             -122.058179
# 2  Pleasant Hill              37.948571             -122.058179
# 3  Pleasant Hill              37.948571             -122.058179
# 4  Pleasant Hill              37.948571             -122.058179
#
#                        Venue  Venue Latitude  Venue Longitude  \
# 0                 Plaza Cafe       37.948306      -122.059647
# 1               Milk Tea Lab       37.948532      -122.058172
# 2  Nation's Giant Hamburgers       37.948692      -122.059679
# 3  Three Brothers From China       37.949411      -122.060963
# 4                  Starbucks       37.948967      -122.057949
#
#        Venue Category
# 0                Café
# 1     Bubble Tea Shop
# 2        Burger Joint
# 3  Chinese Restaurant
# 4         Coffee Shop

# %% [markdown]
# ## One-hot-encoding for Contra Costa County:

# %%
ccc_grouped = oneHotEncoding(ccc_venues)
ccc_grouped.head()
# Out:
#   Neighborhood       ATM  Accessories Store  Afghan Restaurant  \
# 0      Antioch  0.000000           0.000000           0.000000
# 1    Brentwood  0.000000           0.008621           0.000000
# 2      Concord  0.010158           0.004515           0.000000
# 3     Danville  0.010638           0.000000           0.010638
# 4   El Cerrito  0.000000           0.000000           0.000000
#
#    American Restaurant    Arcade  Art Gallery  Arts & Crafts Store  \
# 0             0.000000  0.000000          0.0             0.000000
# 1             0.017241  0.000000          0.0             0.000000
# 2             0.002257  0.006772          0.0             0.007901
# 3             0.042553  0.000000          0.0             0.000000
# 4             0.000000  0.000000          0.0             0.000000
#
#    Asian Restaurant  Auto Dealership  ...  Veterinarian  Video Game Store  \
# 0          0.000000         0.000000  ...      0.010526          0.000000
# 1          0.008621         0.000000  ...      0.000000          0.017241
# 2          0.014673         0.004515  ...      0.000000          0.001129
# 3          0.000000         0.000000  ...      0.000000          0.000000
# 4          0.020408         0.000000  ...      0.000000          0.000000
#
#    Video Store  Vietnamese Restaurant  Warehouse Store  Weight Loss Center  \
# 0     0.000000               0.031579         0.000000            0.000000
# 1     0.000000               0.000000         0.000000            0.000000
# 2     0.001129               0.022573         0.002257            0.000000
# 3     0.000000               0.000000         0.000000            0.000000
# 4     0.010204               0.010204         0.000000            0.010204
#
#    Wine Bar  Wings Joint  Women's Store  Yoga Studio
# 0  0.000000     0.010526       0.000000     0.000000
# 1  0.000000     0.008621       0.008621     0.000000
# 2  0.000000     0.000000       0.001129     0.000000
# 3  0.010638     0.000000       0.000000     0.010638
# 4  0.000000     0.010204       0.000000     0.020408
#
# [5 rows x 220 columns]

# %% [markdown]
# ## Finding top venues in Contra Costa County cities:

# %%
findTopVenues(ccc_grouped, num_top_venues)
# Out:
# ----Antioch----
#                   venue  freq
# 0                  Bank  0.05
# 1  Fast Food Restaurant  0.05
# 2           Pizza Place  0.05
# 3        Sandwich Place  0.04
# 4         Grocery Store  0.04
#
#
# ----Brentwood----
#             venue  freq
# 0  Clothing Store  0.07
# 1  Ice Cream Shop  0.05
# 2     Pizza Place  0.05
# 3  Sandwich Place  0.04
# 4   Grocery Store  0.03
#
#
# ----Concord----
#                 venue  freq
# 0  Mexican Restaurant  0.09
# 1      Sandwich Place  0.03
# 2         Coffee Shop  0.03
# 3          Laundromat  0.02
# 4   Indian Restaurant  0.02
#
#
# ----Danville----
#                 venue  freq
# 0         Pizza Place  0.05
# 1      Sandwich Place  0.05
# 2  Italian Restaurant  0.04
# 3     Thai Restaurant  0.04
# 4       Grocery Store  0.04
#
#
# ----El Cerrito----
#                 venue  freq
# 0         Coffee Shop  0.04
# 1   Mobile Phone Shop  0.04
# 2         Pizza Place  0.04
# 3    Sushi Restaurant  0.03
# 4  Chinese Restaurant  0.03
#
#
# ----Hercules----
#                 venue  freq
# 0         Pizza Place  0.09
# 1                Bank  0.09
# 2           BBQ Joint  0.09
# 3  Chinese Restaurant  0.04
# 4        Tennis Court  0.04
#
#
# ----Lafayette----
#                      venue  freq
# 0       Mexican Restaurant  0.06
# 1              Coffee Shop  0.06
# 2                     Bank  0.05
# 3  New American Restaurant  0.05
# 4              Pizza Place  0.05
#
#
# ----Martinez----
#                   venue  freq
# 0    Chinese Restaurant  0.10
# 1    Mexican Restaurant  0.08
# 2  Fast Food Restaurant  0.06
# 3        Sandwich Place  0.06
# 4           Coffee Shop  0.04
#
#
# ----Moraga----
#                 venue  freq
# 0  Italian Restaurant  0.06
# 1  Chinese Restaurant  0.06
# 2         Coffee Shop  0.06
# 3      Discount Store  0.06
# 4         Pizza Place  0.04
#
#
# ----Pinole----
#               venue  freq
# 0        Donut Shop  0.07
# 1      Burger Joint  0.07
# 2  Sushi Restaurant  0.07
# 3          Pharmacy  0.07
# 4       Coffee Shop  0.07
#
#
# ----Pittsburg----
#                    venue  freq
# 0   Fast Food Restaurant  0.09
# 1     Mexican Restaurant  0.07
# 2  Vietnamese Restaurant  0.06
# 3         Sandwich Place  0.05
# 4     Chinese Restaurant  0.04
#
#
# ----Pleasant Hill----
#                  venue  freq
# 0          Pizza Place  0.05
# 1     Sushi Restaurant  0.04
# 2  American Restaurant  0.04
# 3   Chinese Restaurant  0.04
# 4   Mexican Restaurant  0.04
#
#
# ----Richmond----
#                 venue  freq
# 0   Korean Restaurant  0.10
# 1    Asian Restaurant  0.10
# 2                Café  0.10
# 3      Massage Studio  0.05
# 4  Dim Sum Restaurant  0.05
#
#
# ----San Pablo----
#                   venue  freq
# 0  Fast Food Restaurant  0.09
# 1           Pizza Place  0.08
# 2    Chinese Restaurant  0.06
# 3        Sandwich Place  0.06
# 4            Donut Shop  0.04
#
#
# ----San Ramon----
#              venue  freq
# 0      Coffee Shop  0.07
# 1  Bubble Tea Shop  0.05
# 2      Pizza Place  0.05
# 3   Sandwich Place  0.04
# 4    Shopping Mall  0.03
#
#
# ----Walnut Creek----
#                     venue  freq
# 0             Coffee Shop  0.05
# 1         Thai Restaurant  0.03
# 2  Furniture / Home Store  0.03
# 3     American Restaurant  0.03
# 4          Clothing Store  0.03

# %% [markdown]
# 10 out of 16 of these stores (approximately 65%) of the cities in Contra Costa county had some beverage venue comparable to pearl milk tea as one of their top venues. This is certainly better than, for instance Santa Clara County, but also does not prove anything definitive yet.

# %% [markdown]
# # Analysis Part 2: <a name = "analysis2"></a>

# %% [markdown]
# From the first part of our analysis, we were able to determine the popularity of milk tea stores in each county in the bay area. Here is a summary table of our results:
#
# |   County     | Percentage of cities with high competition |
# | :---------   | :----------------------------------------: |
# |    S.F.      |        100% (only one city in county)      |
# | San Mateo    |          64%                               |
# | Santa Clara  |        100% (with 15 cities in county)     |
# | Alameda      |          58%                               |
# | Contra Costa |            65%                             |
#
# Clearly, S.F. County and Santa Clara County are not great options for opening a new pearl milk tea store due to how strong the competition is in the cities of the county. Unless one was opening a new location of a well-established chain, it would be very difficult to succeed in these counties. This reduces our potential list of locations to San Mateo county, Alameda county, and Contra Costa county.
#
# **Now, to narrow it down further to a single county, let us compare the average ratings of milk tea stores in each county:**

# %% [markdown]
# ## Finding average ratings:

# %%
def getMeanRating(df_county):
    mean = df_county['rating'].mean()
    
    return mean

# %%
sanMateoAVG = getMeanRating(df_sanMateo)
alamedaAVG = getMeanRating(df_alameda)
cccAVG = getMeanRating(df_ccc)

print("San Mateo Average: " + str(sanMateoAVG))
print("Alameda Average: " + str(alamedaAVG))
print("Contra Costa Average: " + str(cccAVG))
# Out:
# San Mateo Average: 3.863013698630137
# Alameda Average: 3.721590909090909
# Contra Costa Average: 3.7686567164179103

# %% [markdown]
# We note that Alameda county has the lowest average rating for their milk tea stores. **We will make the assumption that this means the competition in Alameda county is the lowest. This is not a guarantee!** The following analysis can be performed for any of the above counties, so it can be repeated and tried again. For simplicity, we will stick to using Alameda county in the below analysis.
#
# Now that we have selected Alameda county, we need to further determine which city we would like to go into. Once again, the map of the boba shops in the area is below:

# %%
mapCounty(df_alameda, 'grey', '#C0C0C0')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_e2aaacee1c9143ea8b89a59615fa875a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e2aaacee1c9143ea8b89a59615fa875a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e2aaacee1c9143ea8b89a59615fa875a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_e2aaacee1c9143ea8b89a59615fa875a%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B37.7790262%2C-122.4199061%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Converting top venues in Alameda into a dataframe:

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = alameda_grouped['Neighborhood']

for ind in np.arange(alameda_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(alameda_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#   Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0      Alameda       Bubble Tea Shop                   Bar
# 1       Albany       Thai Restaurant     Indian Restaurant
# 2     Berkeley           Coffee Shop                  Café
# 3       Dublin           Coffee Shop        Sandwich Place
# 4      Fremont    Chinese Restaurant       Bubble Tea Shop
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0        Sandwich Place    Chinese Restaurant       Thai Restaurant
# 1          Liquor Store             Pet Store           Pizza Place
# 2       Thai Restaurant   Japanese Restaurant           Pizza Place
# 3   Japanese Restaurant                Bakery           Pizza Place
# 4           Coffee Shop           Pizza Place  Fast Food Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0   American Restaurant           Coffee Shop    Mexican Restaurant
# 1        Breakfast Spot                  Café    Mexican Restaurant
# 2                  Pool             Bookstore       Bubble Tea Shop
# 3         Grocery Store  Fast Food Restaurant      Asian Restaurant
# 4        Sandwich Place         Grocery Store     Indian Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 0    Italian Restaurant       Sushi Restaurant
# 1                   Bar            Coffee Shop
# 2    Chinese Restaurant         Ice Cream Shop
# 3    Chinese Restaurant      Indian Restaurant
# 4                Bakery           Dessert Shop

# %% [markdown]
# ## K-Means-Clustering:

# %%
from sklearn.cluster import KMeans

# set number of clusters
kclusters = 5

alameda_grouped_clustering = alameda_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(alameda_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([4, 1, 4, 0, 0, 3, 3, 0, 4, 3], dtype=int32)

# %%
# add clustering labels
#neighborhoods_venues_sorted.insert(0, 'Label', kmeans.labels_)

alameda_merged = df_alameda

# merge manhattan_grouped with manhattan_data to add latitude/longitude for each neighborhood
alameda_merged = alameda_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on = 'city')

alameda_merged.head(100) # check the last columns!
# Out:
#                         name  rating        city        lat        long  \
# 0              99% Tea House     4.5     Fremont  37.562950 -122.010040
# 1                    One Tea     4.5     Fremont  37.489067 -121.929414
# 2               Royaltea USA     4.0     Fremont  37.551315 -121.993850
# 3      TECO Tea & Coffee Bar     4.5     Fremont  37.553694 -121.981043
# 4                      T-LAB     4.0     Fremont  37.576149 -122.043705
# ..                       ...     ...         ...        ...         ...
# 95           99 Ranch Market     3.5  Pleasanton  37.699560 -121.873260
# 96  Menchie's  Frozen Yogurt     4.0      Dublin  37.703721 -121.851480
# 97               Blossom Bee     4.0      Dublin  37.710858 -121.926420
# 98             Berry Delight     3.0  Pleasanton  37.694629 -121.931563
# 99           New Thai Bistro     4.5  Pleasanton  37.677180 -121.875780
#
#     Label  Labels  Cluster Label  Cluster Labels 1st Most Common Venue  \
# 0       0       0              0               0    Chinese Restaurant
# 1       0       0              0               0    Chinese Restaurant
# 2       0       0              0               0    Chinese Restaurant
# 3       0       0              0               0    Chinese Restaurant
# 4       0       0              0               0    Chinese Restaurant
# ..    ...     ...            ...             ...                   ...
# 95      3       3              3               3           Coffee Shop
# 96      0       0              0               0           Coffee Shop
# 97      0       0              0               0           Coffee Shop
# 98      3       3              3               3           Coffee Shop
# 99      3       3              3               3           Coffee Shop
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0        Bubble Tea Shop           Coffee Shop           Pizza Place
# 1        Bubble Tea Shop           Coffee Shop           Pizza Place
# 2        Bubble Tea Shop           Coffee Shop           Pizza Place
# 3        Bubble Tea Shop           Coffee Shop           Pizza Place
# 4        Bubble Tea Shop           Coffee Shop           Pizza Place
# ..                   ...                   ...                   ...
# 95           Pizza Place        Clothing Store         Grocery Store
# 96        Sandwich Place   Japanese Restaurant                Bakery
# 97        Sandwich Place   Japanese Restaurant                Bakery
# 98           Pizza Place        Clothing Store         Grocery Store
# 99           Pizza Place        Clothing Store         Grocery Store
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0   Fast Food Restaurant        Sandwich Place         Grocery Store
# 1   Fast Food Restaurant        Sandwich Place         Grocery Store
# 2   Fast Food Restaurant        Sandwich Place         Grocery Store
# 3   Fast Food Restaurant        Sandwich Place         Grocery Store
# 4   Fast Food Restaurant        Sandwich Place         Grocery Store
# ..                   ...                   ...                   ...
# 95    Chinese Restaurant        Sandwich Place        Ice Cream Shop
# 96           Pizza Place         Grocery Store  Fast Food Restaurant
# 97           Pizza Place         Grocery Store  Fast Food Restaurant
# 98    Chinese Restaurant        Sandwich Place        Ice Cream Shop
# 99    Chinese Restaurant        Sandwich Place        Ice Cream Shop
#
#     8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0       Indian Restaurant                Bakery           Dessert Shop
# 1       Indian Restaurant                Bakery           Dessert Shop
# 2       Indian Restaurant                Bakery           Dessert Shop
# 3       Indian Restaurant                Bakery           Dessert Shop
# 4       Indian Restaurant                Bakery           Dessert Shop
# ..                    ...                   ...                    ...
# 95  Vietnamese Restaurant      Sushi Restaurant     Mexican Restaurant
# 96       Asian Restaurant    Chinese Restaurant      Indian Restaurant
# 97       Asian Restaurant    Chinese Restaurant      Indian Restaurant
# 98  Vietnamese Restaurant      Sushi Restaurant     Mexican Restaurant
# 99  Vietnamese Restaurant      Sushi Restaurant     Mexican Restaurant
#
# [100 rows x 19 columns]

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# create map
map_clusters = folium.Map(location=[sf_latitude, sf_longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(alameda_merged['lat'], alameda_merged['long'], alameda_merged['city'], alameda_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_f157c05099f74f3ca640412ec844ab5e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f157c05099f74f3ca640412ec844ab5e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f157c05099f74f3ca640412ec844ab5e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_f157c05099f74f3ca640412ec844ab5e%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B37.7790262%2C-122.4199061%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20% ...

# %%
alameda_merged.loc[alameda_merged['Cluster Labels'] == 0, alameda_merged.columns[[1] + list(range(5, alameda_merged.shape[1]))]]
# Out:
#      rating  Label  Labels  Cluster Label  Cluster Labels  \
# 0       4.5      0       0              0               0
# 1       4.5      0       0              0               0
# 2       4.0      0       0              0               0
# 3       4.5      0       0              0               0
# 4       4.0      0       0              0               0
# ..      ...    ...     ...            ...             ...
# 127     4.0      0       0              0               0
# 128     3.5      0       0              0               0
# 139     4.0      0       0              0               0
# 140     4.0      0       0              0               0
# 141     4.0      0       0              0               0
#
#     1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0      Chinese Restaurant       Bubble Tea Shop           Coffee Shop
# 1      Chinese Restaurant       Bubble Tea Shop           Coffee Shop
# 2      Chinese Restaurant       Bubble Tea Shop           Coffee Shop
# 3      Chinese Restaurant       Bubble Tea Shop           Coffee Shop
# 4      Chinese Restaurant       Bubble Tea Shop           Coffee Shop
# ..                    ...                   ...                   ...
# 127    Chinese Restaurant       Bubble Tea Shop           Coffee Shop
# 128    Chinese Restaurant       Bubble Tea Shop           Coffee Shop
# 139    Chinese Restaurant       Bubble Tea Shop           Coffee Shop
# 140    Chinese Restaurant       Bubble Tea Shop           Coffee Shop
# 141    Chinese Restaurant       Bubble Tea Shop           Coffee Shop
#
#     4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0             Pizza Place  Fast Food Restaurant        Sandwich Place
# 1             Pizza Place  Fast Food Restaurant        Sandwich Place
# 2             Pizza Place  Fast Food Restaurant        Sandwich Place
# 3             Pizza Place  Fast Food Restaurant        Sandwich Place
# 4             Pizza Place  Fast Food Restaurant        Sandwich Place
# ..                    ...                   ...                   ...
# 127           Pizza Place  Fast Food Restaurant        Sandwich Place
# 128           Pizza Place  Fast Food Restaurant        Sandwich Place
# 139           Pizza Place  Fast Food Restaurant        Sandwich Place
# 140           Pizza Place  Fast Food Restaurant        Sandwich Place
# 141           Pizza Place  Fast Food Restaurant        Sandwich Place
#
#     7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0           Grocery Store     Indian Restaurant                Bakery
# 1           Grocery Store     Indian Restaurant                Bakery
# 2           Grocery Store     Indian Restaurant                Bakery
# 3           Grocery Store     Indian Restaurant                Bakery
# 4           Grocery Store     Indian Restaurant                Bakery
# ..                    ...                   ...                   ...
# 127         Grocery Store     Indian Restaurant                Bakery
# 128         Grocery Store     Indian Restaurant                Bakery
# 139         Grocery Store     Indian Restaurant                Bakery
# 140         Grocery Store     Indian Restaurant                Bakery
# 141         Grocery Store     Indian Restaurant                Bakery
#
#     10th Most Common Venue
# 0             Dessert Shop
# 1             Dessert Shop
# 2             Dessert Shop
# 3             Dessert Shop
# 4             Dessert Shop
# ..                     ...
# 127           Dessert Shop
# 128           Dessert Shop
# 139           Dessert Shop
# 140           Dessert Shop
# 141           Dessert Shop
#
# [70 rows x 15 columns]

# %%
alameda_merged.loc[alameda_merged['Cluster Labels'] == 1, alameda_merged.columns[[1] + list(range(5, alameda_merged.shape[1]))]]
# Out:
#      rating  Label  Labels  Cluster Label  Cluster Labels  \
# 143     3.5      1       1              1               1
#
#     1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 143       Thai Restaurant     Indian Restaurant          Liquor Store
#
#     4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 143             Pet Store           Pizza Place        Breakfast Spot
#
#     7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 143                  Café    Mexican Restaurant                   Bar
#
#     10th Most Common Venue
# 143            Coffee Shop

# %%
alameda_merged.loc[alameda_merged['Cluster Labels'] == 2, alameda_merged.columns[[1] + list(range(5, alameda_merged.shape[1]))]]
# Out:
#      rating  Label  Labels  Cluster Label  Cluster Labels  \
# 25      3.5      2       2              2               2
# 30      4.0      2       2              2               2
# 31      3.5      2       2              2               2
# 33      3.5      2       2              2               2
# 34      3.5      2       2              2               2
# 37      3.5      2       2              2               2
# 115     3.5      2       2              2               2
# 118     4.5      2       2              2               2
# 123     3.5      2       2              2               2
# 126     4.0      2       2              2               2
#
#      1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 25   Vietnamese Restaurant         Grocery Store      Asian Restaurant
# 30   Vietnamese Restaurant         Grocery Store      Asian Restaurant
# 31   Vietnamese Restaurant         Grocery Store      Asian Restaurant
# 33   Vietnamese Restaurant         Grocery Store      Asian Restaurant
# 34   Vietnamese Restaurant         Grocery Store      Asian Restaurant
# 37   Vietnamese Restaurant         Grocery Store      Asian Restaurant
# 115  Vietnamese Restaurant         Grocery Store      Asian Restaurant
# 118  Vietnamese Restaurant         Grocery Store      Asian Restaurant
# 123  Vietnamese Restaurant         Grocery Store      Asian Restaurant
# 126  Vietnamese Restaurant         Grocery Store      Asian Restaurant
#
#     4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 25        Thai Restaurant    Chinese Restaurant                Bakery
# 30        Thai Restaurant    Chinese Restaurant                Bakery
# 31        Thai Restaurant    Chinese Restaurant                Bakery
# 33        Thai Restaurant    Chinese Restaurant                Bakery
# 34        Thai Restaurant    Chinese Restaurant                Bakery
# 37        Thai Restaurant    Chinese Restaurant                Bakery
# 115       Thai Restaurant    Chinese Restaurant                Bakery
# 118       Thai Restaurant    Chinese Restaurant                Bakery
# 123       Thai Restaurant    Chinese Restaurant                Bakery
# 126       Thai Restaurant    Chinese Restaurant                Bakery
#
#     7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 25                   Café      Ramen Restaurant                  Bank
# 30                   Café      Ramen Restaurant                  Bank
# 31                   Café      Ramen Restaurant                  Bank
# 33                   Café      Ramen Restaurant                  Bank
# 34                   Café      Ramen Restaurant                  Bank
# 37                   Café      Ramen Restaurant                  Bank
# 115                  Café      Ramen Restaurant                  Bank
# 118                  Café      Ramen Restaurant                  Bank
# 123                  Café      Ramen Restaurant                  Bank
# 126                  Café      Ramen Restaurant                  Bank
#
#     10th Most Common Venue
# 25    Fast Food Restaurant
# 30    Fast Food Restaurant
# 31    Fast Food Restaurant
# 33    Fast Food Restaurant
# 34    Fast Food Restaurant
# 37    Fast Food Restaurant
# 115   Fast Food Restaurant
# 118   Fast Food Restaurant
# 123   Fast Food Restaurant
# 126   Fast Food Restaurant

# %%
alameda_merged.loc[alameda_merged['Cluster Labels'] == 3, alameda_merged.columns[[1] + list(range(5, alameda_merged.shape[1]))]]
# Out:
#      rating  Label  Labels  Cluster Label  Cluster Labels  \
# 38      4.0      3       3              3               3
# 58      4.0      3       3              3               3
# 69      3.5      3       3              3               3
# 73      4.0      3       3              3               3
# 74      4.5      3       3              3               3
# 76      3.5      3       3              3               3
# 77      4.0      3       3              3               3
# 80      4.0      3       3              3               3
# 83      3.5      3       3              3               3
# 84      2.5      3       3              3               3
# 85      3.0      3       3              3               3
# 86      4.0      3       3              3               3
# 89      4.0      3       3              3               3
# 90      4.0      3       3              3               3
# 94      3.0      3       3              3               3
# 95      3.5      3       3              3               3
# 98      3.0      3       3              3               3
# 99      4.5      3       3              3               3
# 104     2.5      3       3              3               3
# 105     3.0      3       3              3               3
# 129     3.5      3       3              3               3
# 130     3.5      3       3              3               3
# 131     4.0      3       3              3               3
# 132     4.0      3       3              3               3
# 133     4.5      3       3              3               3
# 134     4.0      3       3              3               3
# 135     4.0      3       3              3               3
# 136     4.0      3       3              3               3
# 137     3.5      3       3              3               3
# 138     4.0      3       3              3               3
# 146     4.5      3       3              3               3
# 147     5.0      3       3              3               3
# 148     2.5      3       3              3               3
# 149     4.0      3       3              3               3
# 150     4.0      3       3              3               3
# 151     3.5      3       3              3               3
# 152     3.5      3       3              3               3
# 153     2.5      3       3              3               3
# 154     3.5      3       3              3               3
# 155     3.5      3       3              3               3
# 156     2.0      3       3              3               3
# 157     4.0      3       3              3               3
# 158     3.5      3       3              3               3
# 159     4.0      3       3              3               3
# 161     2.5      3       3              3               3
# 162     2.0      3       3              3               3
# 163     3.5      3       3              3               3
# 167     4.5      3       3              3               3
# 168     4.0      3       3              3               3
# 169     3.5      3       3              3               3
# 170     3.5      3       3              3               3
# 171     4.0      3       3              3               3
# 172     3.5      3       3              3               3
# 173     4.0      3       3              3               3
# 174     4.0      3       3              3               3
# 175     3.0      3       3              3               3
#
#     1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 38            Pizza Place      Sushi Restaurant    Chinese Restaurant
# 58            Pizza Place      Sushi Restaurant    Chinese Restaurant
# 69            Pizza Place      Sushi Restaurant    Chinese Restaurant
# 73            Coffee Shop           Pizza Place        Clothing Store
# 74            Coffee Shop           Pizza Place        Clothing Store
# 76            Coffee Shop           Pizza Place        Clothing Store
# 77            Coffee Shop           Pizza Place        Clothing Store
# 80            Coffee Shop           Pizza Place        Clothing Store
# 83            Coffee Shop           Pizza Place        Clothing Store
# 84            Coffee Shop           Pizza Place        Clothing Store
# 85            Coffee Shop           Pizza Place        Clothing Store
# 86            Coffee Shop           Pizza Place        Clothing Store
# 89            Coffee Shop           Pizza Place        Clothing Store
# 90            Coffee Shop           Pizza Place        Clothing Store
# 94            Coffee Shop           Pizza Place        Clothing Store
# 95            Coffee Shop           Pizza Place        Clothing Store
# 98            Coffee Shop           Pizza Place        Clothing Store
# 99            Coffee Shop           Pizza Place        Clothing Store
# 104        Clothing Store           Pizza Place        Sandwich Place
# 105           Coffee Shop           Pizza Place        Clothing Store
# 129    Mexican Restaurant                   Bar        Sandwich Place
# 130    Mexican Restaurant                   Bar        Sandwich Place
# 131    Mexican Restaurant                   Bar        Sandwich Place
# 132        Clothing Store           Pizza Place        Sandwich Place
# 133        Clothing Store           Pizza Place        Sandwich Place
# 134        Clothing Store           Pizza Place        Sandwich Place
# 135        Clothing Store           Pizza Place        Sandwich Place
# 136        Clothing Store           Pizza Place        Sandwich Place
# 137        Clothing Store           Pizza Place        Sandwich Place
# 138        Clothing Store           Pizza Place        Sandwich Place
# 146    Mexican Restaurant                   Bar        Sandwich Place
# 147    Mexican Restaurant                   Bar        Sandwich Place
# 148    Mexican Restaurant                   Bar        Sandwich Place
# 149           Pizza Place      Sushi Restaurant    Chinese Restaurant
# 150    Mexican Restaurant                   Bar        Sandwich Place
# 151           Pizza Place      Sushi Restaurant    Chinese Restaurant
# 152           Pizza Place      Sushi Restaurant    Chinese Restaurant
# 153           Pizza Place      Sushi Restaurant    Chinese Restaurant
# 154           Pizza Place      Sushi Restaurant    Chinese Restaurant
# 155           Pizza Place      Sushi Restaurant    Chinese Restaurant
# 156           Pizza Place      Sushi Restaurant    Chinese Restaurant
# 157           Pizza Place      Sushi Restaurant    Chinese Restaurant
# 158           Pizza Place      Sushi Restaurant    Chinese Restaurant
# 159           Pizza Place      Sushi Restaurant    Chinese Restaurant
# 161           Pizza Place      Sushi Restaurant    Chinese Restaurant
# 162           Pizza Place      Sushi Restaurant    Chinese Restaurant
# 163           Pizza Place      Sushi Restaurant    Chinese Restaurant
# 167    Mexican Restaurant                   Bar        Sandwich Place
# 168           Pizza Place      Sushi Restaurant    Chinese Restaurant
# 169           Pizza Place      Sushi Restaurant    Chinese Restaurant
# 170           Pizza Place      Sushi Restaurant    Chinese Restaurant
# 171    Mexican Restaurant                   Bar        Sandwich Place
# 172           Pizza Place      Sushi Restaurant    Chinese Restaurant
# 173    Mexican Restaurant                   Bar        Sandwich Place
# 174    Mexican Restaurant                   Bar        Sandwich Place
# 175           Pizza Place      Sushi Restaurant    Chinese Restaurant
#
#     4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 38                   Bank    Mexican Restaurant          Burger Joint
# 58                   Bank    Mexican Restaurant          Burger Joint
# 69                   Bank    Mexican Restaurant          Burger Joint
# 73          Grocery Store    Chinese Restaurant        Sandwich Place
# 74          Grocery Store    Chinese Restaurant        Sandwich Place
# 76          Grocery Store    Chinese Restaurant        Sandwich Place
# 77          Grocery Store    Chinese Restaurant        Sandwich Place
# 80          Grocery Store    Chinese Restaurant        Sandwich Place
# 83          Grocery Store    Chinese Restaurant        Sandwich Place
# 84          Grocery Store    Chinese Restaurant        Sandwich Place
# 85          Grocery Store    Chinese Restaurant        Sandwich Place
# 86          Grocery Store    Chinese Restaurant        Sandwich Place
# 89          Grocery Store    Chinese Restaurant        Sandwich Place
# 90          Grocery Store    Chinese Restaurant        Sandwich Place
# 94          Grocery Store    Chinese Restaurant        Sandwich Place
# 95          Grocery Store    Chinese Restaurant        Sandwich Place
# 98          Grocery Store    Chinese Restaurant        Sandwich Place
# 99          Grocery Store    Chinese Restaurant        Sandwich Place
# 104            Shoe Store    Mexican Restaurant  Fast Food Restaurant
# 105         Grocery Store    Chinese Restaurant        Sandwich Place
# 129           Pizza Place           Coffee Shop    Chinese Restaurant
# 130           Pizza Place           Coffee Shop    Chinese Restaurant
# 131           Pizza Place           Coffee Shop    Chinese Restaurant
# 132            Shoe Store    Mexican Restaurant  Fast Food Restaurant
# 133            Shoe Store    Mexican Restaurant  Fast Food Restaurant
# 134            Shoe Store    Mexican Restaurant  Fast Food Restaurant
# 135            Shoe Store    Mexican Restaurant  Fast Food Restaurant
# 136            Shoe Store    Mexican Restaurant  Fast Food Restaurant
# 137            Shoe Store    Mexican Restaurant  Fast Food Restaurant
# 138            Shoe Store    Mexican Restaurant  Fast Food Restaurant
# 146           Pizza Place           Coffee Shop    Chinese Restaurant
# 147           Pizza Place           Coffee Shop    Chinese Restaurant
# 148           Pizza Place           Coffee Shop    Chinese Restaurant
# 149                  Bank    Mexican Restaurant          Burger Joint
# 150           Pizza Place           Coffee Shop    Chinese Restaurant
# 151                  Bank    Mexican Restaurant          Burger Joint
# 152                  Bank    Mexican Restaurant          Burger Joint
# 153                  Bank    Mexican Restaurant          Burger Joint
# 154                  Bank    Mexican Restaurant          Burger Joint
# 155                  Bank    Mexican Restaurant          Burger Joint
# 156                  Bank    Mexican Restaurant          Burger Joint
# 157                  Bank    Mexican Restaurant          Burger Joint
# 158                  Bank    Mexican Restaurant          Burger Joint
# 159                  Bank    Mexican Restaurant          Burger Joint
# 161                  Bank    Mexican Restaurant          Burger Joint
# 162                  Bank    Mexican Restaurant          Burger Joint
# 163                  Bank    Mexican Restaurant          Burger Joint
# 167           Pizza Place           Coffee Shop    Chinese Restaurant
# 168                  Bank    Mexican Restaurant          Burger Joint
# 169                  Bank    Mexican Restaurant          Burger Joint
# 170                  Bank    Mexican Restaurant          Burger Joint
# 171           Pizza Place           Coffee Shop    Chinese Restaurant
# 172                  Bank    Mexican Restaurant          Burger Joint
# 173           Pizza Place           Coffee Shop    Chinese Restaurant
# 174           Pizza Place           Coffee Shop    Chinese Restaurant
# 175                  Bank    Mexican Restaurant          Burger Joint
#
#     7th Most Common Venue  8th Most Common Venue 9th Most Common Venue  \
# 38             Nail Salon               Pharmacy           Coffee Shop
# 58             Nail Salon               Pharmacy           Coffee Shop
# 69             Nail Salon               Pharmacy           Coffee Shop
# 73         Ice Cream Shop  Vietnamese Restaurant      Sushi Restaurant
# 74         Ice Cream Shop  Vietnamese Restaurant      Sushi Restaurant
# 76         Ice Cream Shop  Vietnamese Restaurant      Sushi Restaurant
# 77         Ice Cream Shop  Vietnamese Restaurant      Sushi Restaurant
# 80         Ice Cream Shop  Vietnamese Restaurant      Sushi Restaurant
# 83         Ice Cream Shop  Vietnamese Restaurant      Sushi Restaurant
# 84         Ice Cream Shop  Vietnamese Restaurant      Sushi Restaurant
# 85         Ice Cream Shop  Vietnamese Restaurant      Sushi Restaurant
# 86         Ice Cream Shop  Vietnamese Restaurant      Sushi Restaurant
# 89         Ice Cream Shop  Vietnamese Restaurant      Sushi Restaurant
# 90         Ice Cream Shop  Vietnamese Restaurant      Sushi Restaurant
# 94         Ice Cream Shop  Vietnamese Restaurant      Sushi Restaurant
# 95         Ice Cream Shop  Vietnamese Restaurant      Sushi Restaurant
# 98         Ice Cream Shop  Vietnamese Restaurant      Sushi Restaurant
# 99         Ice Cream Shop  Vietnamese Restaurant      Sushi Restaurant
# 104     Accessories Store             Restaurant           Coffee Shop
# 105        Ice Cream Shop  Vietnamese Restaurant      Sushi Restaurant
# 129      Sushi Restaurant  Vietnamese Restaurant        Clothing Store
# 130      Sushi Restaurant  Vietnamese Restaurant        Clothing Store
# 131      Sushi Restaurant  Vietnamese Restaurant        Clothing Store
# 132     Accessories Store             Restaurant           Coffee Shop
# 133     Accessories Store             Restaurant           Coffee Shop
# 134     Accessories Store             Restaurant           Coffee Shop
# 135     Accessories Store             Restaurant           Coffee Shop
# 136     Accessories Store             Restaurant           Coffee Shop
# 137     Accessories Store             Restaurant           Coffee Shop
# 138     Accessories Store             Restaurant           Coffee Shop
# 146      Sushi Restaurant  Vietnamese Restaurant        Clothing Store
# 147      Sushi Restaurant  Vietnamese Restaurant        Clothing Store
# 148      Sushi Restaurant  Vietnamese Restaurant        Clothing Store
# 149            Nail Salon               Pharmacy           Coffee Shop
# 150      Sushi Restaurant  Vietnamese Restaurant        Clothing Store
# 151            Nail Salon               Pharmacy           Coffee Shop
# 152            Nail Salon               Pharmacy           Coffee Shop
# 153            Nail Salon               Pharmacy           Coffee Shop
# 154            Nail Salon               Pharmacy           Coffee Shop
# 155            Nail Salon               Pharmacy           Coffee Shop
# 156            Nail Salon               Pharmacy           Coffee Shop
# 157            Nail Salon               Pharmacy           Coffee Shop
# 158            Nail Salon               Pharmacy           Coffee Shop
# 159            Nail Salon               Pharmacy           Coffee Shop
# 161            Nail Salon               Pharmacy           Coffee Shop
# 162            Nail Salon               Pharmacy           Coffee Shop
# 163            Nail Salon               Pharmacy           Coffee Shop
# 167      Sushi Restaurant  Vietnamese Restaurant        Clothing Store
# 168            Nail Salon               Pharmacy           Coffee Shop
# 169            Nail Salon               Pharmacy           Coffee Shop
# 170            Nail Salon               Pharmacy           Coffee Shop
# 171      Sushi Restaurant  Vietnamese Restaurant        Clothing Store
# 172            Nail Salon               Pharmacy           Coffee Shop
# 173      Sushi Restaurant  Vietnamese Restaurant        Clothing Store
# 174      Sushi Restaurant  Vietnamese Restaurant        Clothing Store
# 175            Nail Salon               Pharmacy           Coffee Shop
#
#     10th Most Common Venue
# 38      Salon / Barbershop
# 58      Salon / Barbershop
# 69      Salon / Barbershop
# 73      Mexican Restaurant
# 74      Mexican Restaurant
# 76      Mexican Restaurant
# 77      Mexican Restaurant
# 80      Mexican Restaurant
# 83      Mexican Restaurant
# 84      Mexican Restaurant
# 85      Mexican Restaurant
# 86      Mexican Restaurant
# 89      Mexican Restaurant
# 90      Mexican Restaurant
# 94      Mexican Restaurant
# 95      Mexican Restaurant
# 98      Mexican Restaurant
# 99      Mexican Restaurant
# 104         Ice Cream Shop
# 105     Mexican Restaurant
# 129                   Bank
# 130                   Bank
# 131                   Bank
# 132         Ice Cream Shop
# 133         Ice Cream Shop
# 134         Ice Cream Shop
# 135         Ice Cream Shop
# 136         Ice Cream Shop
# 137         Ice Cream Shop
# 138         Ice Cream Shop
# 146                   Bank
# 147                   Bank
# 148                   Bank
# 149     Salon / Barbershop
# 150                   Bank
# 151     Salon / Barbershop
# 152     Salon / Barbershop
# 153     Salon / Barbershop
# 154     Salon / Barbershop
# 155     Salon / Barbershop
# 156     Salon / Barbershop
# 157     Salon / Barbershop
# 158     Salon / Barbershop
# 159     Salon / Barbershop
# 161     Salon / Barbershop
# 162     Salon / Barbershop
# 163     Salon / Barbershop
# 167                   Bank
# 168     Salon / Barbershop
# 169     Salon / Barbershop
# 170     Salon / Barbershop
# 171                   Bank
# 172     Salon / Barbershop
# 173                   Bank
# 174                   Bank
# 175     Salon / Barbershop

# %%
alameda_merged.loc[alameda_merged['Cluster Labels'] == 4, alameda_merged.columns[[1] + list(range(5, alameda_merged.shape[1]))]]
# Out:
#      rating  Label  Labels  Cluster Label  Cluster Labels  \
# 39      4.0      4       4              4               4
# 40      3.5      4       4              4               4
# 41      4.0      4       4              4               4
# 42      4.0      4       4              4               4
# 43      4.0      4       4              4               4
# 44      4.0      4       4              4               4
# 45      4.0      4       4              4               4
# 46      3.0      4       4              4               4
# 47      4.0      4       4              4               4
# 48      4.0      4       4              4               4
# 49      4.0      4       4              4               4
# 50      4.0      4       4              4               4
# 51      3.5      4       4              4               4
# 52      3.5      4       4              4               4
# 53      3.5      4       4              4               4
# 54      3.5      4       4              4               4
# 55      4.0      4       4              4               4
# 56      4.0      4       4              4               4
# 57      4.5      4       4              4               4
# 59      3.5      4       4              4               4
# 60      4.0      4       4              4               4
# 61      4.0      4       4              4               4
# 62      3.0      4       4              4               4
# 63      3.5      4       4              4               4
# 64      3.5      4       4              4               4
# 65      5.0      4       4              4               4
# 66      4.5      4       4              4               4
# 67      2.5      4       4              4               4
# 68      4.5      4       4              4               4
# 70      3.5      4       4              4               4
# 71      4.0      4       4              4               4
# 72      3.5      4       4              4               4
# 142     4.0      4       4              4               4
# 144     3.5      4       4              4               4
# 145     3.5      4       4              4               4
# 160     3.5      4       4              4               4
# 164     3.5      4       4              4               4
# 165     4.5      4       4              4               4
# 166     3.5      4       4              4               4
#
#     1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 39     Chinese Restaurant                  Café           Coffee Shop
# 40     Chinese Restaurant                  Café           Coffee Shop
# 41     Chinese Restaurant                  Café           Coffee Shop
# 42            Coffee Shop                  Café       Thai Restaurant
# 43     Chinese Restaurant                  Café           Coffee Shop
# 44            Coffee Shop                  Café       Thai Restaurant
# 45        Bubble Tea Shop                   Bar        Sandwich Place
# 46     Chinese Restaurant                  Café           Coffee Shop
# 47     Chinese Restaurant                  Café           Coffee Shop
# 48            Coffee Shop                  Café       Thai Restaurant
# 49            Coffee Shop                  Café       Thai Restaurant
# 50            Coffee Shop                  Café       Thai Restaurant
# 51        Bubble Tea Shop                   Bar        Sandwich Place
# 52            Coffee Shop                  Café       Thai Restaurant
# 53        Bubble Tea Shop                   Bar        Sandwich Place
# 54     Chinese Restaurant                  Café           Coffee Shop
# 55     Chinese Restaurant                  Café           Coffee Shop
# 56        Bubble Tea Shop                   Bar        Sandwich Place
# 57     Chinese Restaurant                  Café           Coffee Shop
# 59     Chinese Restaurant                  Café           Coffee Shop
# 60            Coffee Shop                  Café       Thai Restaurant
# 61     Chinese Restaurant                  Café           Coffee Shop
# 62     Chinese Restaurant                  Café           Coffee Shop
# 63        Bubble Tea Shop                   Bar        Sandwich Place
# 64        Bubble Tea Shop                   Bar        Sandwich Place
# 65     Chinese Restaurant                  Café           Coffee Shop
# 66     Chinese Restaurant                  Café           Coffee Shop
# 67     Chinese Restaurant                  Café           Coffee Shop
# 68     Chinese Restaurant                  Café           Coffee Shop
# 70     Chinese Restaurant                  Café           Coffee Shop
# 71            Coffee Shop                  Café       Thai Restaurant
# 72     Chinese Restaurant                  Café           Coffee Shop
# 142    Chinese Restaurant                  Café           Coffee Shop
# 144           Coffee Shop                  Café       Thai Restaurant
# 145           Coffee Shop                  Café       Thai Restaurant
# 160       Bubble Tea Shop                   Bar        Sandwich Place
# 164       Bubble Tea Shop                   Bar        Sandwich Place
# 165    Chinese Restaurant                  Café           Coffee Shop
# 166       Bubble Tea Shop                   Bar        Sandwich Place
#
#      4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 39   Vietnamese Restaurant        Sandwich Place                Bakery
# 40   Vietnamese Restaurant        Sandwich Place                Bakery
# 41   Vietnamese Restaurant        Sandwich Place                Bakery
# 42     Japanese Restaurant           Pizza Place                  Pool
# 43   Vietnamese Restaurant        Sandwich Place                Bakery
# 44     Japanese Restaurant           Pizza Place                  Pool
# 45      Chinese Restaurant       Thai Restaurant   American Restaurant
# 46   Vietnamese Restaurant        Sandwich Place                Bakery
# 47   Vietnamese Restaurant        Sandwich Place                Bakery
# 48     Japanese Restaurant           Pizza Place                  Pool
# 49     Japanese Restaurant           Pizza Place                  Pool
# 50     Japanese Restaurant           Pizza Place                  Pool
# 51      Chinese Restaurant       Thai Restaurant   American Restaurant
# 52     Japanese Restaurant           Pizza Place                  Pool
# 53      Chinese Restaurant       Thai Restaurant   American Restaurant
# 54   Vietnamese Restaurant        Sandwich Place                Bakery
# 55   Vietnamese Restaurant        Sandwich Place                Bakery
# 56      Chinese Restaurant       Thai Restaurant   American Restaurant
# 57   Vietnamese Restaurant        Sandwich Place                Bakery
# 59   Vietnamese Restaurant        Sandwich Place                Bakery
# 60     Japanese Restaurant           Pizza Place                  Pool
# 61   Vietnamese Restaurant        Sandwich Place                Bakery
# 62   Vietnamese Restaurant        Sandwich Place                Bakery
# 63      Chinese Restaurant       Thai Restaurant   American Restaurant
# 64      Chinese Restaurant       Thai Restaurant   American Restaurant
# 65   Vietnamese Restaurant        Sandwich Place                Bakery
# 66   Vietnamese Restaurant        Sandwich Place                Bakery
# 67   Vietnamese Restaurant        Sandwich Place                Bakery
# 68   Vietnamese Restaurant        Sandwich Place                Bakery
# 70   Vietnamese Restaurant        Sandwich Place                Bakery
# 71     Japanese Restaurant           Pizza Place                  Pool
# 72   Vietnamese Restaurant        Sandwich Place                Bakery
# 142  Vietnamese Restaurant        Sandwich Place                Bakery
# 144    Japanese Restaurant           Pizza Place                  Pool
# 145    Japanese Restaurant           Pizza Place                  Pool
# 160     Chinese Restaurant       Thai Restaurant   American Restaurant
# 164     Chinese Restaurant       Thai Restaurant   American Restaurant
# 165  Vietnamese Restaurant        Sandwich Place                Bakery
# 166     Chinese Restaurant       Thai Restaurant   American Restaurant
#
#     7th Most Common Venue 8th Most Common Venue  \
# 39     Mexican Restaurant                   Bar
# 40     Mexican Restaurant                   Bar
# 41     Mexican Restaurant                   Bar
# 42              Bookstore       Bubble Tea Shop
# 43     Mexican Restaurant                   Bar
# 44              Bookstore       Bubble Tea Shop
# 45            Coffee Shop    Mexican Restaurant
# 46     Mexican Restaurant                   Bar
# 47     Mexican Restaurant                   Bar
# 48              Bookstore       Bubble Tea Shop
# 49              Bookstore       Bubble Tea Shop
# 50              Bookstore       Bubble Tea Shop
# 51            Coffee Shop    Mexican Restaurant
# 52              Bookstore       Bubble Tea Shop
# 53            Coffee Shop    Mexican Restaurant
# 54     Mexican Restaurant                   Bar
# 55     Mexican Restaurant                   Bar
# 56            Coffee Shop    Mexican Restaurant
# 57     Mexican Restaurant                   Bar
# 59     Mexican Restaurant                   Bar
# 60              Bookstore       Bubble Tea Shop
# 61     Mexican Restaurant                   Bar
# 62     Mexican Restaurant                   Bar
# 63            Coffee Shop    Mexican Restaurant
# 64            Coffee Shop    Mexican Restaurant
# 65     Mexican Restaurant                   Bar
# 66     Mexican Restaurant                   Bar
# 67     Mexican Restaurant                   Bar
# 68     Mexican Restaurant                   Bar
# 70     Mexican Restaurant                   Bar
# 71              Bookstore       Bubble Tea Shop
# 72     Mexican Restaurant                   Bar
# 142    Mexican Restaurant                   Bar
# 144             Bookstore       Bubble Tea Shop
# 145             Bookstore       Bubble Tea Shop
# 160           Coffee Shop    Mexican Restaurant
# 164           Coffee Shop    Mexican Restaurant
# 165    Mexican Restaurant                   Bar
# 166           Coffee Shop    Mexican Restaurant
#
#              9th Most Common Venue 10th Most Common Venue
# 39   Vegetarian / Vegan Restaurant        Bubble Tea Shop
# 40   Vegetarian / Vegan Restaurant        Bubble Tea Shop
# 41   Vegetarian / Vegan Restaurant        Bubble Tea Shop
# 42              Chinese Restaurant         Ice Cream Shop
# 43   Vegetarian / Vegan Restaurant        Bubble Tea Shop
# 44              Chinese Restaurant         Ice Cream Shop
# 45              Italian Restaurant       Sushi Restaurant
# 46   Vegetarian / Vegan Restaurant        Bubble Tea Shop
# 47   Vegetarian / Vegan Restaurant        Bubble Tea Shop
# 48              Chinese Restaurant         Ice Cream Shop
# 49              Chinese Restaurant         Ice Cream Shop
# 50              Chinese Restaurant         Ice Cream Shop
# 51              Italian Restaurant       Sushi Restaurant
# 52              Chinese Restaurant         Ice Cream Shop
# 53              Italian Restaurant       Sushi Restaurant
# 54   Vegetarian / Vegan Restaurant        Bubble Tea Shop
# 55   Vegetarian / Vegan Restaurant        Bubble Tea Shop
# 56              Italian Restaurant       Sushi Restaurant
# 57   Vegetarian / Vegan Restaurant        Bubble Tea Shop
# 59   Vegetarian / Vegan Restaurant        Bubble Tea Shop
# 60              Chinese Restaurant         Ice Cream Shop
# 61   Vegetarian / Vegan Restaurant        Bubble Tea Shop
# 62   Vegetarian / Vegan Restaurant        Bubble Tea Shop
# 63              Italian Restaurant       Sushi Restaurant
# 64              Italian Restaurant       Sushi Restaurant
# 65   Vegetarian / Vegan Restaurant        Bubble Tea Shop
# 66   Vegetarian / Vegan Restaurant        Bubble Tea Shop
# 67   Vegetarian / Vegan Restaurant        Bubble Tea Shop
# 68   Vegetarian / Vegan Restaurant        Bubble Tea Shop
# 70   Vegetarian / Vegan Restaurant        Bubble Tea Shop
# 71              Chinese Restaurant         Ice Cream Shop
# 72   Vegetarian / Vegan Restaurant        Bubble Tea Shop
# 142  Vegetarian / Vegan Restaurant        Bubble Tea Shop
# 144             Chinese Restaurant         Ice Cream Shop
# 145             Chinese Restaurant         Ice Cream Shop
# 160             Italian Restaurant       Sushi Restaurant
# 164             Italian Restaurant       Sushi Restaurant
# 165  Vegetarian / Vegan Restaurant        Bubble Tea Shop
# 166             Italian Restaurant       Sushi Restaurant

# %% [markdown]
# # Results and Discussion <a name = "results"></a>

# %% [markdown]
# We began with dividing up our data set into 5 Bay Area counties in order to make analysis more specialized. From there, the top venues in each county were identified to determine which areas have particularily strong showings of beverage industry competition. This ruled out San Francisco county and Santa Clara County, both of which contained bubble tea stores or another comparable good in the top 5 venues for every single city in the counties.
#
#
# This narrowed our search to San Mateo, Alameda, and Contra Costa counties, where we used the `bayarea_boba_spots.csv` in order to see the popularity data of the milk tea stores in the counties. From this, we determined that Alameda has the lowest ratings, hence we assume that the competition is the weakest there (this assumption had to be made for this project's sake; this project focuses on data science, not necessarily the business strategy side). This analysis lead us to selecting Alameda county as our desired county.
#
#
# With Alameda county, we performed K-means-clustering to see which particular city to open our new store in. The results of the K-Means-clustering grouped areas together that share similar popular venues. Doing this allows for us to see which areas in Alameda county have the fiercest competition, which we want to avoid. For example, cluster 4 represents areas with chinese restaurants and cafes as their top venues, while cluster 2 grouped areas with vietnamese restaurants as their top venues.
#
#
# Out of these 5 clusters, **cluster 2 appears to be the optimal place to open a pearl milk tea store given that there seems to be the least competition there** (the first instance of a comparable good venue appears as 7th most common, whereas the first instance appears earlier for all the other clusters e.g. cluster 0). ***Reexamining the dataframe, this corresponds to Union City.***

# %% [markdown]
# # Conclusion <a name = "conclusion"></a>

# %% [markdown]
# The purpose of this project was to take a large data set of the milk tea stores in the Bay Area and determine where the optimal location for a new milk tea store would be if one was a new business owner. Using the Foursquare API, we were able to divide the Bay Area into 5 major counties, then further focus in on individual cities using the `bayarea_boba_spots.csv` to compare rating data. K-means-clustering was used to then cluster these stores by characteristics to see which area would be most competitive, thus allowing us to find the area with least competition.
#
# Our analysis showed that when considering the popularity of pearl milk tea stores and other beverage industry companies that sell similar goods, **the optimal location for opening a new, non-franchised store in the immediate Bay Area is in Union City, Alameda County.**
